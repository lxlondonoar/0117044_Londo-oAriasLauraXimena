# %% [markdown]
# # Notebook Basics
# ---

# %%
'''EJERCICIO 1: 
    
Sin utilizar el comando abs, escribir un programa que calcule e imprima el 
valor absoluto de cualquier número (sea entero o decimal).'''

while True:
    try:
        X = float(input("Digite un número: "))
        #Lectura de datos desde el teclado
        break 
        #Captación del error
    except ValueError:
        print("Debe ingresar números. Intentelo nuevamente.")
        
if X < 0:
    X *= (-1)
    
print(f'El valor absoluto del número es: {X}')
# Out:
# Digite un número: -5
# El valor absoluto del número es: 5.0

# %% [markdown]
# This lesson assumes that the user has Jupyter [installed](https://jupyter.readthedocs.io/en/latest/install.html) and that the notebook server can be started by running:
#
#     jupyter notebook
#
# For more details on how to run the notebook server, see [Running the Notebook Server](Running%20the%20Notebook%20Server.ipynb).

# %%
'''EJERCICIO 2: 
    
Leer dos números enteros y determinar si la magnitud de la diferencia entre los 
dos es un número primo.'''

while True:
    try:
        x = int(input("Digite un número entero: "))   # Lectura de datos desde 
        y = int(input("Digite otro número entero: ")) # el teclado.
        break                                          
    except ValueError:                                # Captación de error.
        print("El número que ingresó no es entero. "  # Salida por pantalla.
              "Intentelo de nuevo.")

dif = x - y                        # Diferencia entre los dos números
                                                      
if dif < 0:
    dif *= (-1)


def n_primo(dif):                  # Fúnción para saber si un número es primo.
    for i in range(2, (dif // 2)):
        return(dif % i) != 0


if n_primo(dif):
    print("La magnitud de la diferencia entre "      # Salida por pantalla.
          "los dos es un número primo.")
else:
    print("La magnitud de la diferencia entre "      # Salida por pantalla.
          "los dos no es un número primo.")

# %%
"""EJERCICIO 3:
    
Iterar a través de los primeros cien enteros positivos, buscando los 
múltiplos de 3 e imprimiendo y almacenándolos en una lista hasta encontrar los 
primeros 15 de ellos. Una vez encontrados, continuar iterando en busca de los 
múltiplos de 4 y almacenarlos en otra lista."""

#Se definen las variables:
cont = 0       #Contador que permite saber la cantidad de múltiplos de 3 hallados

lista3 = []    #Lista de los primeros 15 múltiplos de 3.

lista4 = []    #Lista de múltiplos de 4 posteriores al 15°  múltiplo  de 3

#Se define un ciclo for que itera a través de los primeros 100 enteros.
#Se agregan a "lista3" los primeros 15 múltiplos de 3 (hasta que cont=15).
#Se agregan a "lista4" los múltiplos de 4 siguientes al último valor de 
#"lista3"
for i in range(1,101):
    if (cont < 15) and (i%3 == 0):
            lista3.append(i)
            cont=cont+1
    
    elif cont==15 and i%4==0:
            lista4.append(i)
 
#Salida de pantalla
print('La siguiente, es la lista de los primeros 15 múltiplos de 3, entre los '  
      'primeros 100 enteros positivos:''\n' f'{lista3}''\n')
    
print('La siguiente, es la lista de múltiplos de 4 posteriores al '  
      '15° múltiplo de 3 entre los 100 primeros enteros positivos:' '\n'

# %% [markdown]
# ## The Dashboard
# ---

# %%
'''EJERCICIO 4: 

    Hacer un programa que lea las coordenadas (x1,y1,r1) y (x2,y2,r2) que 
corresponden al centro y al radio de dos círculos.
Lea un punto de coordenadas (a,b). Determinar si (a,b) está contenido: 
    
    a) dentro del círculo 1.
    b) dentro del círculo 2.
    c) dentro de ambos círculos.
    d) fuera de ambos círculos. 

Recordemos que el círculo es el lugar geométrico de los puntos del plano cuya 
distancia a otro punto fijo, llamado centro, es menor o igual que una cantidad 
constante, llamada radio.'''

while True:
    try:
        xc1 = float(input("Digite la coordenada en x "    # Lectura de datos
                          "del centro del Círculo 1: "))  # desde el teclado.
        yc1 = float(input("Digite la coordenada en y "
                          "del centro del Círculo 1: "))
        rc1 = float(input("Digite el radio del Círculo 1: "))
        xc2 = float(input("Digite la coordenada en x "
                          "del centro del Círculo 2: "))
        yc2 = float(input("Digite la coordenada en y "
                          "del centro del Círculo 2: "))
        rc2 = float(input("Digite el radio del Círculo 2: "))
        x   = float(input("Digite la coordenada en x de un punto: "))
        y   = float(input("Digite la coordenada en y de un punto: "))

        break  
# Captación de error.                                                                      
    except ValueError:                                    
        print("Debe ingresar un número real. Intentelo de nuevo.")

A = ((xc1 - rc1) < x < (xc1 + rc1)) and ((yc1 - rc1) < y < (yc1 + rc1))              
    # Límites del Círculo 1.
B = (xc2 - rc2 < x < (xc2 + rc2)) and ((yc2 - rc2) < y < (yc2 + rc2))                
    # Límites del Círculo 2.

# Salida por pantalla.
if A:
    print(f"El punto de coordenadas ({x}, {y}) "
          "está contenido en el Círculo 1.")            
if B:
    print(f"El punto de coordenadas ({x}, {y}) "
          "está contenido en el Círculo 2.")            
if A and B:
    print(f"Por tanto, el punto de coordenadas ({x}, {y})" 
          " está contenido en ambos círculos ")        
else:
    print(f"El punto de coordenadas ({x}, {y})"         
          " no está contenido en ningún círculo.")

# %%
"""EJERCICIO 5: 
    
Escribir un programa que reciba una cadena de texto y reporte:

    a) cuántas letras vocales en mayúscula se entraron;
    b) cuántas letras con tilde se entraron (minúsculas y mayúsculas);
    c) cuántos dígitos se entraron,
    d) cuántos espacios se entraron;
    e) cuántas palabras reservadas se entraron.

Utilizar para ello los métodos de cadenas especializados como .isupper(), 
.isdigit(), etc. y la palabra reservada in."""

import keyword          #Se importa la librería keyword

#Lectura de datos desde el teclado. 
txt = (input("Ingrese una cadena de texto: "))

vow = 'AEIOU'           #Cadena que contiene las vocales mayúsculas
til_cap = 'ÁÉÍÓÚ'       #Cadena que contiene Las vocales mayúsculas tildadas
til_min = 'áéíóú'       #Cadena que contiene Las vocales minúsculas tildadas
esp = ' '               #Cadena que contiene un esoacio

key = (keyword.kwlist)  #De la librería que se importó con anterioridad, se 
                        #define key como la lista de palabras restringidas

#Se hace al texto ingresado una cadena
lista_cadena = txt.split(' ')

cont_vow = 0            #Contador de vocales mayúsculas
cont_til = 0            #Contador de letras tildadas
cont_dig = 0            #Contador de dígitos
cont_esp = 0            #Contador de espacios
cont_res = 0            #Contador de palabras restringidas

#Se itera a través de la cadena, modificando los contadores dependiendo del 
#caso
for i in range(len(txt)):
    if txt[i] in vow or txt[i] in til_cap:
        cont_vow += 1 
        
    if txt[i] in til_cap or txt[i] in til_min:
        cont_til += 1
        
    if txt[i].isdigit() is True:
        cont_dig += 1
        
    if txt[i] in esp:
        cont_esp += 1 

for j in lista_cadena:
    if j in key:
        cont_res+=1

#Salida en pantalla del resultado
print('la cadena ingresada contiene: ' '\n' f'{cont_vow} vocales en mayúscula'
      '\n' f'{cont_til} letras con tilde entre mayúsculas y minúsculas' '\n'
      f'{cont_dig} dígitos' '\n' f'{cont_esp} espacios' '\n' f'{cont_res} '
      'palabras reservadas')

# %%
"""EJERCICIO 6:

Leer una cadena de texto y organizar alfabéticamente cada una de las letras que 
la componen, repitiendo cada una tantas veces como se encuentra. Por ejemplo, 
la cadena ‘tarea importante’ será ‘aaaeeimnoprrttt’. (Note que no se incluyen 
los espacios)."""

#Lectura de datos desde el teclado. 
while True:
    try:                                                                 
        s = input('Ingrese una cadena de texto: ')
        car_perm = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUV\
                            WXYZ ')
        if set(s).issubset(car_perm):
            break
        else:
            print('Solo puede ingresar letras en la cadena')
    except ValueError:
        print ('Ingrese de nuevo la cadena')

lista_s = list(s)    #la cadena de texto s se transforma en lista (lista_s)
lista_s.sort()       #Mediante el comando sort se ordenan los elementos de la
#Lista_s

posicion=0           

#Se itera a través de lista_s
#Se eliminan los espacios de la lista.

while posicion < len(lista_s):
    if lista_s[posicion] == ' ':
        lista_s.pop(posicion)
    else:
        posicion=posicion+1
        break 

#li es la lista_s que vuelve a transformarse en cadena.
li=''.join(lista_s)

#Salida en pantalla de los caracteres ordenados.
print(f'Los caracteres de la cadena, organizados alfabéticamente, son: \n{li}')

# %%
"""EJERCICIO 7:

Leer una lista de números ya ordenados de forma ascendente y verificar que 
dicha lista está ordenada. Luego, leer un número e insertarlo en la lista en la 
posición que le corresponde a dicho número."""

#Se definen 2 valores iniciales i y j y una bandera
i = 0 
j = 1
band = 0

while band == 0:
    lista = [] #Se crea una lista vacía donde se agregarán los elementos dados
             #por el usuario.
    
    #Lectura de datos desde el teclado. Se pide al usuario ingresar el tamaño 
    #de la lista a tratar.
    while True:
        try:
            
            qu = int(input("Ingrese el numero de elementos: "))
            if qu > 0: break
            else:
                print('El número de elementos debe ser positivo')
            break
        except ValueError:
            print('El número de elementos debe ser un número real')
 
#Lectura de datos desde el teclado. A través de un rango qu Se pide al usuario 
#ingresar los elementos de la lista.         
    for x in range(qu):
        
        while True:
            try:
                valor=int(input("Ingrese un valor entero: "))
                lista.append(valor)
                break
            except ValueError:
                print('El elemento de la lista debe ser un número.')
  
#Con la bandera definida al inicio, con este ciclo while se itera a través de
#los elementos de la lista y si no están ordenados pedir que sea ingresada de 
#nuevo.
    while j < qu:
        
        if lista [i] < lista [j]:
            i = i + 1
            j = j + 1
            band = 1
        else:
            print("Lista no ordenada. Ingrese una lista que SÍ esté ordenada.")
            break
            band = 0
           
maytem = 0  #Se cera una variable donde se almacena el mayor temporal hasta
            #que el usuario ingrese el número a insertar en la lista

#Lectura de datos desde el teclado. Se pide al usuario ingresar el elemento
#que quiera insertar en la lista.
num = int(input("Ingrese un número para posicionar en la lista: "))
i = 0
j = 1

#Se inserta el número dado por el usuario en la posición que corresponda dentro
#de la lista.

while j < qu:
        num1 = lista[i] 
        num2 = lista[j]
        if (num >= num1) and (num <= num2):
            lista.insert(j, num)
            break
        else:
            i = i + 1
            j = j + 1
            
if num < lista[0]:
    lista.insert(0, num)
elif num > lista[qu-1]:
    lista.insert(qu, num)
    
print(f'La lista, con el número ingresado en su posición respectiva es {lista}')

# %%
"""EJERCICIO 8:
    
Leer una lista de números enteros y determinar cual es el segundo elemento 
mayor de dicha lista. No utilizar ningún tipo de algoritmo de ordenamiento 
para realizar este ejercicio. Por ejemplo, en la lista [11, 22, 3, 4, 22], el 
segundo número mayor sería el 11; de otro lado, en la lista [1, 1, 1, 1, 1] no 
existe un segundo elemento mayor."""
    
def leer_lista_enteros():
    '''esta funcion lee una lista de numeros enteros'''
    while True:
        try:
            x = list(eval(input('Ingrese los numeros enteros que desea \
incluir en su lista separados por una coma\n')))
            if all(type(i) is int for i in x):break
            else:print('solo se aceptan numeros enteros')
           
        except: print('Por favor solo ingrese numeros enteros separados por \
una coma')
    return(x)
    
L = leer_lista_enteros()  #se llama la funcion
Lcopia = L.copy()         #copia para no afectar la lista original

Nmayor = Lcopia[0]        #se almacena el valor mayor en la lista
for i in Lcopia:          #se busca el valor mayor dentro de la lista
    if i > Nmayor:
        Nmayor = i

while True: 
    Lcopia.remove(Nmayor)
    if Nmayor not in Lcopia: 
        break                

if len(Lcopia) == 0:
    print('En la lista no existe segundo elemento mayor')

else:    
    Nmayor2 = Lcopia[0]   #ahora se procede a buscar el numero mayor dentro de
    for i in Lcopia:      #la nueva lista
        if i > Nmayor2:
            Nmayor2 = i

    print(f'El segundo elemento mayor de: {L}\nEs: {Nmayor2}')

# %%
"""EJERCICIO 9:

Escribir un programa que calcule términos de la sucesión Un+1 = 3 Un + 1 si 
Un es impar y U n+1 = Un / 2 si Un es par. El programa tiene que pedir el 
término U0 y el número de términos a calcular."""

import numpy as np      #se importa la libreria

def leer_entero(y):    #funcionn para leer cualquier numero
    '''funcion para leer numeros enteros'''
    while True:
        try:
            x = int(input(f'{y}\n'))
            break
        except:
            print('solo ingrese valores numericos enteros')
            
    return x

Uo = leer_entero('Digame el valor de U(0):  ') 

terminos = leer_entero('Digame cuantos terminos tiene:  ')

L = np.zeros(terminos)      #se crea una lista de zeros del numero de terminos
                            #indicado
L[0] = Uo                   #el primer valor de la lista es u(0)

for i in range(len(L)-1):   #iternando por los indices de la lista
    if L[i]%2 == 0:          
        L[i+1] = L[i]//2    
    else:
        L[i+1] = 3*L[i] +1

print(f'Los terminos de la sucesion son:\n{L}') #Salida por pantalla

# %%
"""EJERCICIO 10:

#Leer una matriz e imprimir el vector que aparece cuando la matriz se desenreda 
#en forma de espiral que gira en el sentido horario a partir de la esquina 
#inferior derecha."""

def leer_matriz():
    '''funcion para leer una matriz de enteros'''
    def leer_entero(y): #funcionn para leer cualquier numero
        '''funcion para leer numeros enteros'''
        while True:
            try:
                x = int(input(f'{y}\n'))
                break
            except:
                print('solo ingrese valores numericos enteros')
                
        return x
    x = leer_entero('Ingrese el numero de filas de la matriz')  
    y = leer_entero('Ingrese el numero de columnas de la matriz')  
    MATRIZ = [[0 for c in range(y)] for f in range(x)] #Matriz de ceros
                                                       
    for i in range(x):      #Se itera por cada elemento de la matriz para
        for r in range(y):  #pedirle al usuario entrar el dato correspondiente
            MATRIZ[i][r] = leer_entero(f'ingrese el valor ({i+1}, {r+1}) de \
su matriz')            
    return(MATRIZ) 
    
M = leer_matriz()   #se llama la funcion leer_matriz para ingresar la matriz
M_copia = M.copy()  #copio la matriz
L = []              #lista cuando la matriz se desenreda

while True:
    for i in range (-1,-len(M_copia[0])-1,-1): #Fila de abajo al reves
        L.append(M_copia[-1][i])      
    for i in range (-2,-len(M_copia),-1):      #Columna 0 al reves
        L.append(M_copia[i][0])
    for i in range (0,len(M_copia[0])):        #Pprimera fila
        L.append(M_copia[0][i]) 
    for i in range (1,len(M_copia)-1):         #Ultima columna en el orden 
        L.append(M_copia[i][-1])               #necesario
    
    B=[]                            #extrae una matriz para volver a empezar a 
    for i in range (1,len(M_copia)-1):    #extraer cosas (matriz interna)
        B.append(M_copia[i][1:len(M_copia[i])-1])    
    
    M_copia = B                            
 
    if len(M_copia) == 0: break
    
print(f'''el vector solicitado es:{L}''')

# %%
'''EJERCICIO 11:

Diseñar una función de tres parámetros que pida la altura y anchura de un 
rectángulo, y el carácter a utilizar para dibujarlo.'''

def fun_rectángulo(altura, anchura, carácter):
    for i in range(altura):
        for j in range(anchura):
            print(carácter, end=" ")
        print()

while True:
    try:
        altura   = int(input("Digite la altura del rectángulo: "))
        anchura  = int(input("Digite la anchura del rectángulo: "))
        break
    except ValueError:
        print("Debe ingresar valores enteros.")

carácter = input("Carácter a utilizar: ")

fun_rectángulo(altura, anchura, carácter)

# %%
'''EJERCICIO 12:

Diseñar una función que pida la anchura de un triángulo y lo dibuje con 
caracteres producto (*).'''

def fun_triángulo_1(anchura):        #Función triángulo creciente
    for i in range(1, anchura + 1):
        for j in range(i):
            print("* ", end="")
        print()

def fun_triángulo_2(anchura):        #Función triángulo decreciente
    for i in range(1, anchura):
        for j in range(anchura - i):
            print("* ", end="")
        print()

while True:
    try:
        anchura = int(input("Digite la anchura del triángulo: "))
        if anchura >= 0:
            break
        else:
            print("Debe ingresar valores positivos. Intentelo nuevamente.")
    except ValueError:
        print("Debe ingresar valores enteros. Intentelo nuevamente.")

fun_triángulo_1(anchura)
fun_triángulo_2(anchura)

# %%
'''EJERCICIO 13:
    
Diseñar una función que pida dos años y escriba cuántos años bisiestos hay 
entre esas dos fechas (incluidos los dos años).'''

def es_bisiesto(t):
    return t % 400 == 0 or (t % 100 != 0 and t % 4 == 0)

print("Contador de años bisiestos")
inicio = int(input("Escriba un año: "))
print("Escriba otro año posterior a", str(inicio) + ": ", end="")
final = int(input())
while final < inicio:
    print(final, "no es mayor que", str(inicio) + ". Inténtelo de nuevo: ",
          end="")
    final = int(input())

contador = 0
for i in range(inicio, final + 1):
    if es_bisiesto(i):
        contador += 1

print("De", inicio, "a", final, "hay", final - inicio + 1, "año(s),",
      contador, "de ellos bisiesto(s).")

# %%
'''EJERCICIO 14:

Diseñar una función que proponga sumas de números positivos (dos números entre 
1 y 100) al usuario y compruebela respuesta. El programa continuará hasta que 
se acierten cinco sumas. (Tip: para generar los números enteros aleatorios, 
existe la función random.randint(a,b) de la librería random).'''

from random import randint

def fun_sumas(x):

    contador = 0
    
    while contador < 5:
        m = randint(0,100)
        n = randint(0,100)
        suma = m + n
        print(f"{m} + {n} =")
        while True:
            try:
                x = int(input("Digite su respuesta: "))
                if x >= 0:
                    break
                else:
                    print("""Su respuesta debe corresponder a un valor positivo. 
Intentelo de nuevo.""")
            except ValueError:
                print("""Su respuesta debe corresponder a un valor entero. 
Intentelo nuevamente.""")
        if x == suma:
            contador += 1        

    if contador == 5:  
        print("Haz acertado 5 sumas.")
   
fun_sumas(x)

# %%
"""EJERCICIO 15:

Diseñar una función que permita jugar a una versión simplificada del juego 
Master Mind. El juego consistirá en adivinar una cadena de números distintos. 
La función debe pedir la longitud de la cadena (de 2 a 9 cifras) y generar
aleatoriamente un número con esta cantidad de cifras; después el programa debe 
ir pidiendo que intente adivinar la cadena de números. En cada intento, el 
programa informará de cuántos números han sido acertados (el programa 
considerará que se ha acertado un número si coincide el valor y la posición).
"""
    
import random as ran 

long = int(input('Dígame la longitud de la cadena: ')) 

def funcion(): 
    contador_intentos=0 
    num1 ='' 
    if long>=2 and long<=9: 
        for i in range(long):
            a = ran.randint(0,9) 
            num = str(a)  
            num1 = num1 + num  
       print(num1)
        
        usuario = input('Intente adivinar la cadena: ') 
        contador_intentos += 1 
        len_usuario = len(usuario) 
        while  len_usuario != long: 
            usuario = input('La longitud de la cadena ingresada es diferente a\
la inicial. Intenete adivinar la cadena: ')
            len_usuario = len(usuario) 
        aciertos = 0 
        while aciertos < long: 
            aciertos=0
            for j in range(long): 
                if num1[j] == usuario[j]: 
                    aciertos = aciertos + 1 
                    
                print(f'Con {usuario} ha adivinado {aciertos} valores. Felicid\
ades')
                print('Numero de intentos: ',contador_intentos)
                break  
            else:
                usuario = input(f'Con {usuario} ha adivinado {aciertos} valore\
s. Intente adivinar la cadena: ') 
                contador_intentos += 1 
                len_usuario = len(usuario)  
                while  len_usuario != long:
                    
                    usuario = input('La longitud de la cadena ingresada es dif\
erente a la inicial. Intenete adivinar la cadena: ') 
                    len_usuario = len(usuario)
    else:
        print('La longitud de cadena ingresada no se encuentra dentro del para\
metro del ejercicio.')
funcion()

# %% [markdown]
# When the notebook server is first started, a browser will be opened to the notebook dashboard. The dashboard serves as a home page for the notebook. Its main purpose is to display the portion of the filesystem accessible by the user, and to provide an overview of the running kernels, terminals, and parallel clusters.

# %% [markdown]
# ### Files Tab
#
# The files tab provides an interactive view of the portion of the filesystem which is accessible by the user. This is typically rooted by the directory in which the notebook server was started.
#
# The top of the files list displays clickable breadcrumbs of the current directory. It is possible to navigate the filesystem by clicking on these breadcrumbs or on the directories displayed in the notebook list.
#
# A new notebook can be created by clicking on the **`New`** dropdown button at the top of the list, and selecting the desired language kernel.
#
# Notebooks can also be uploaded to the current directory by dragging a notebook file onto the list or by clicking the **`Upload`** button at the top of the list.
#
# <img src="images/dashboard_notebooks_tab_5_0.png" />

# %% [markdown]
# ### Running Tab
#
# The running tab displays the currently running notebooks which are known to the server. This view provides a convenient way to track notebooks that have been started during a long running notebook server session.
#
# Each running notebook will have an orange **`Shutdown`** button which can be used to shutdown its associated kernel. Closing the notebook's page is not sufficient to shutdown a kernel.
#
# Running terminals are also listed, provided that the notebook server is running on an operating system which supports PTY.
#
# <img src="images/dashboard_running_tab_4_0.png" />

# %% [markdown]
# ### Clusters Tab
#
# The clusters tab provides a summary view of [IPython Parallel](https://ipyparallel.readthedocs.io/en/latest/) clusters. The IPython Parallel extension must be [installed](https://github.com/ipython/ipyparallel) in order to use this feature.
#
# <img src="images/dashboard_clusters_tab_4_0.png" />

# %% [markdown]
# ## The Notebook
# ---

# %% [markdown]
# When a notebook is opened, a new browser tab will be created which presents the notebook user interface (UI). This UI allows for interactively editing and running the notebook document.
#
# A new notebook can be created from the dashboard by clicking on the **`Files`** tab, followed by the **`New`** dropdown button, and then selecting the language of choice for the notebook.
#
# An interactive tour of the notebook UI can be started by selecting **`Help -> User Interface Tour`** from the notebook menu bar.

# %% [markdown]
# ### Header
#
# At the top of the notebook document is a header which contains the notebook title, a menubar, and toolbar. This header remains fixed at the top of the screen, even as the body of the notebook is scrolled. The title can be edited in-place (which renames the notebook file), and the menubar and toolbar contain a variety of actions which control notebook navigation and document structure.
#
# <img src="images/notebook_header_4_0.png" />

# %% [markdown]
# ### Body
#
# The body of a notebook is composed of cells. Each cell contains either markdown, code input, code output, or raw text. Cells can be included in any order and edited at-will, allowing for a large ammount of flexibility for constructing a narrative.
#
# - **Markdown cells** - These are used to build a nicely formatted narrative around the code in the document. The majority of this lesson is composed of markdown cells.
#
# - **Code cells** - These are used to define the computational code in the document. They come in two forms: the *input cell* where the user types the code to be executed, and the *output cell* which is the representation of the executed code. Depending on the code, this representation may be a simple scalar value, or something more complex like a plot or an interactive widget.
#
# - **Raw cells** - These are used when text needs to be included in raw form, without execution or transformation.
#
# <img src="images/notebook_body_4_0.png" />

# %% [markdown]
# #### Modality
#
# The notebook user interface is *modal*. This means that the keyboard behaves differently depending upon the current mode of the notebook. A notebook has two modes: **edit** and **command**.
#
# **Edit mode** is indicated by a green cell border and a prompt showing in the editor area. When a cell is in edit mode, you can type into the cell, like a normal text editor.
#
# <img src="images/edit_mode.png">
#
# **Command mode** is indicated by a grey cell border. When in command mode, the structure of the notebook can be modified as a whole, but the text in individual cells cannot be changed. Most importantly, the keyboard is mapped to a set of shortcuts for efficiently performing notebook and cell actions. For example, pressing **`c`** when in command mode, will copy the current cell; no modifier is needed.
#
# <img src="images/command_mode.png">
#
# <br>
# <div class="alert alert-success">
# Enter edit mode by pressing `Enter` or using the mouse to click on a cell's editor area.
# </div>
# <div class="alert alert-success">
# Enter command mode by pressing `Esc` or using the mouse to click *outside* a cell's editor area.
# </div>
# <div class="alert alert-warning">
# Do not attempt to type into a cell when in command mode; unexpected things will happen!
# </div>

# %% [markdown]
# #### Mouse navigation
#
# The first concept to understand in mouse-based navigation is that **cells can be selected by clicking on them.** The currently selected cell is indicated with a grey or green border depending on whether the notebook is in edit or command mode. Clicking inside a cell's editor area will enter edit mode. Clicking on the prompt or the output area of a cell will enter command mode.
#
# The second concept to understand in mouse-based navigation is that **cell actions usually apply to the currently selected cell**. For example, to run the code in a cell, select it and then click the <button class='btn btn-default btn-xs'><i class="fa fa-play icon-play"></i></button> button in the toolbar or the **`Cell -> Run`** menu item. Similarly, to copy a cell, select it and then click the <button class='btn btn-default btn-xs'><i class="fa fa-copy icon-copy"></i></button> button in the toolbar or the **`Edit -> Copy`** menu item. With this simple pattern, it should be possible to perform nearly every action with the mouse.
#
# Markdown cells have one other state which can be modified with the mouse. These cells can either be rendered or unrendered. When they are rendered, a nice formatted representation of the cell's contents will be presented. When they are unrendered, the raw text source of the cell will be presented. To render the selected cell with the mouse, click the <button class='btn btn-default btn-xs'><i class="fa fa-play icon-play"></i></button> button in the toolbar or the **`Cell -> Run`** menu item. To unrender the selected cell, double click on the cell.

# %% [markdown]
# #### Keyboard Navigation
#
# The modal user interface of the IPython Notebook has been optimized for efficient keyboard usage. This is made possible by having two different sets of keyboard shortcuts: one set that is active in edit mode and another in command mode.
#
# The most important keyboard shortcuts are **`Enter`**, which enters edit mode, and **`Esc`**, which enters command mode.
#
# In edit mode, most of the keyboard is dedicated to typing into the cell's editor. Thus, in edit mode there are relatively few shortcuts. In command mode, the entire keyboard is available for shortcuts, so there are many more possibilities.
#
# The following images give an overview of the available keyboard shortcuts. These can viewed in the notebook at any time via the **`Help -> Keyboard Shortcuts`** menu item.
#
# <img src="images/notebook_shortcuts_4_0.png">
#
# The following shortcuts have been found to be the most useful in day-to-day tasks:
#
# - Basic navigation: **`enter`**, **`shift-enter`**, **`up/k`**, **`down/j`**
# - Saving the notebook: **`s`**
# - Cell types: **`y`**, **`m`**, **`1-6`**, **`r`**
# - Cell creation: **`a`**, **`b`**
# - Cell editing: **`x`**, **`c`**, **`v`**, **`d`**, **`z`**, **`ctrl+shift+-`**
# - Kernel operations: **`i`**, **`.`**

# %% [markdown]
# ## The Text Editor
# ---

# %% [markdown]
# The notebook application has the ability to edit more than just notebook files and code cells. Any plain text file can be edited using the built-in text editor.
#
# The text editor will be opened in a new browser tab whenever a non-notebook text file is accessed from the dashboard. A new text file can also be created from the dashboard by clicking on the **`Files`** tab, followed by the **`New`** dropdown button, and then selecting **`Text File`**.
#
# The text editor has a header which is similar to that of the notebook's, and includes the document title and a menubar. The syntax highlighting for the text file is determined automatically by the file extension. It can also be set manually via the **`Language`** option in the menubar.
#
# <img src="images/text_editor_4_0.png">

# %% [markdown]
# ## The Terminal
# ---

# %% [markdown]
# If the notebook server is run on an operating system which supports [PTY](https://en.wikipedia.org/wiki/Pseudoterminal) (Linux/Mac), then the notebook application will be able to spawn interactive terminal instances. If the operating system does not support PTY (Windows), the terminal feature will not be enabled.
#
# A new terminal can be spawned from the dashboard by clicking on the **`Files`** tab, followed by the **`New`** dropdown button, and then selecting **`Terminal`**.
#
# The terminal supports all applications which would otherwise run in a PTY, this includes classical terminal applications like Vim, Nano, and Bash.
#
# <img src="images/terminal_4_0.png">
